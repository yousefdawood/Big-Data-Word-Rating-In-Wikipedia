# %%
# %%writefile mapper.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') 

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    for word in words:
        print >> sys.stderr, "reporter:counter:Wiki stats,Total words,%d" % 1
        print "%s\t%d" % (word.lower(), 1)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py

import sys

current_key = None
word_sum = 0
# Out:
# Overwriting reducer.py

# %%
# %%writefile -a reducer.py

for line in sys.stdin:
    try:
        key, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
    if current_key != key:
        if current_key:
            print "%s\t%d" % (current_key, word_sum)
        word_sum = 0
        current_key = key
    word_sum += count

if current_key:
    print "%s\t%d" % (current_key, word_sum)
# Out:
# Appending to reducer.py

# %%
# %%writefile mapper_rating.py

import sys
import re

reload(sys)
sys.setdefaultencoding('utf-8') 

for line in sys.stdin:
    try:
        word, count = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
        
    print "%d\t%s" % (count, word)
# Out:
# Writing mapper_rating.py

# %%
# %%writefile reducer_rating.py

import sys

for line in sys.stdin:
    try:
        count, word = line.strip().split('\t', 1)
        count = int(count)
    except ValueError as e:
        continue
        
    print "%s\t%d" % (word, count)
# Out:
# Writing reducer_rating.py

# %%
# %%bash
#
# OUT_DIR="wordcount"
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming wordCount" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py \
#     -mapper "python mapper.py" \
#     -combiner "python reducer.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
#
# OUT_DIR_2="word_rating"
# NUM_REDUCERS=1
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_2} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming wordCount Rating" \
#     -D mapreduce.job.output.key.comparator.class=org.apache.hadoop.mapreduce.lib.partition.KeyFieldBasedComparator \
#     -D map.output.key.field.separator=\t \
#     -D mapreduce.partition.keycomparator.options=-k1,1nr \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper_rating.py,reducer_rating.py \
#     -mapper "python mapper_rating.py" \
#     -reducer "python reducer_rating.py" \
#     -input ${OUT_DIR} \
#     -output ${OUT_DIR_2} > /dev/null
#
# hdfs dfs -cat ${OUT_DIR_2}/part-00000 | head -7 | tail -1
# Out:
# is	126420
# 20/02/09 14:10:45 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 20/02/09 14:10:45 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 20/02/09 14:10:46 INFO mapred.FileInputFormat: Total input files to process : 1
# 20/02/09 14:10:46 INFO mapreduce.JobSubmitter: number of splits:2
# 20/02/09 14:10:46 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1581247117668_0012
# 20/02/09 14:10:46 INFO impl.YarnClientImpl: Submitted application application_1581247117668_0012
# 20/02/09 14:10:46 INFO mapreduce.Job: The url to track the job: http://46d11b27082c:8088/proxy/application_1581247117668_0012/
# 20/02/09 14:10:46 INFO mapreduce.Job: Running job: job_1581247117668_0012
# 20/02/09 14:10:52 INFO mapreduce.Job: Job job_1581247117668_0012 running in uber mode : false
# 20/02/09 14:10:52 INFO mapreduce.Job:  map 0% reduce 0%
# 20/02/09 14:11:11 INFO mapreduce.Job:  map 16% reduce 0%
# 20/02/09 14:11:17 INFO mapreduce.Job:  map 24% reduce 0%
# 20/02/09 14:11:23 INFO mapreduce.Job:  map 32% reduce 0%
# 20/02/09 14:11:29 INFO mapreduce.Job:  map 40% reduce 0%
# 20/02/09 14:11:35 INFO mapreduce.Job:  map 43% reduce 0%
# 20/02/09 14:11:41 INFO mapreduce.Job:  map 47% reduce 0%
# 20/02/09 14:11:46 INFO mapreduce.Job:  map 48% reduce 0%
# 20/02/09 14:11:47 INFO mapreduce.Job:  map 50% reduce 0%
# 20/02/09 14:11:52 INFO mapreduce.Job:  map 58% reduce 0%
# 20/02/09 14:11:58 INFO mapreduce.Job:  map 66% reduce 0%
# 20/02/09 14:12:04 INFO mapreduce.Job:  map 67% reduce 0%
# 20/02/09 14:12:06 INFO mapreduce.Job:  map 83% reduce 0%
# 20/02/09 14:12:07 INFO mapreduce.Job:  map 100% reduce 0%
# 20/02/09 14:12:14 INFO mapreduce.Job:  map 100% reduce 13%
# 20/02/09 14:12:18 INFO mapreduce.Job:  map 100% reduce 25%
# 20/02/09 14:12:22 INFO mapreduce.Job:  map 100% reduce 38%
# 20/02/09 14:12:24 INFO mapreduce.Job:  map 100% reduce 50%
# 20/02/09 14:12:25 INFO mapreduce.Job:  map 100% reduce 63%
# 20/02/09 14:12:26 INFO mapreduce.Job:  map 100% reduce 75%
# 20/02/09 14:12:27 INFO mapreduce.Job:  map 100% reduce 88%
# 20/02/09 14:12:28 INFO mapreduce.Job:  map 100% reduce 100%
# 20/02/09 14:12:29 INFO mapreduce.Job: Job job_1581247117668_0012 completed successfully
# 20/02/09 14:12:29 INFO mapreduce.Job: Counters: 51
# 	File System Counters
# 		FILE: Number of bytes read=17954826
# 		FILE: Number of bytes written=28257813
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=5370513
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=142923
# 		Total time spent by all reduces in occupied slots (ms)=81503
# 		Total time spent by all map tasks (ms)=142923
# 		Total time spent by all reduce tasks (ms)=81503
# 		Total vcore-milliseconds taken by all map tasks=142923
# 		Total vcore-milliseconds taken by all reduce tasks=81503
# 		Total megabyte-milliseconds taken by all map tasks=146353152
# 		Total megabyte-milliseconds taken by all reduce tasks=83459072
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=11937375
# 		Map output bytes=97842436
# 		Map output materialized bytes=8952763
# 		Input split bytes=228
# 		Combine input records=11937375
# 		Combine output records=640011
# 		Reduce input groups=427175
# 		Reduce shuffle bytes=8952763
# 		Reduce input records=640011
# 		Reduce output records=427175
# 		Spilled Records=1920033
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=2483
# 		CPU time spent (ms)=231070
# 		Physical memory (bytes) snapshot=1928859648
# 		Virtual memory (bytes) snapshot=19151499264
# 		Total committed heap usage (bytes)=1293418496
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	Wiki stats
# 		Total words=11937375
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=5370513
# 20/02/09 14:12:29 INFO streaming.StreamJob: Output directory: wordcount
# rm: `word_rating': No such file or directory
# 20/02/09 14:12:33 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 20/02/09 14:12:34 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 20/02/09 14:12:34 INFO mapred.FileInputFormat: Total input files to process : 8
# 20/02/09 14:12:35 INFO mapreduce.JobSubmitter: number of splits:8
# 20/02/09 14:12:35 INFO Configuration.deprecation: map.output.key.field.separator is deprecated. Instead, use mapreduce.map.output.key.field.separator
# 20/02/09 14:12:35 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1581247117668_0013
# 20/02/09 14:12:35 INFO impl.YarnClientImpl: Submitted application application_1581247117668_0013
# 20/02/09 14:12:35 INFO mapreduce.Job: The url to track the job: http://46d11b27082c:8088/proxy/application_1581247117668_0013/
# 20/02/09 14:12:35 INFO mapreduce.Job: Running job: job_1581247117668_0013
# 20/02/09 14:12:41 INFO mapreduce.Job: Job job_1581247117668_0013 running in uber mode : false
# 20/02/09 14:12:41 INFO mapreduce.Job:  map 0% reduce 0%
# 20/02/09 14:13:17 INFO mapreduce.Job:  map 2% reduce 0%
# 20/02/09 14:13:22 INFO mapreduce.Job:  map 75% reduce 0%
# 20/02/09 14:13:51 INFO mapreduce.Job:  map 100% reduce 0%
# 20/02/09 14:13:54 INFO mapreduce.Job:  map 100% reduce 100%
# 20/02/09 14:13:54 INFO mapreduce.Job: Job job_1581247117668_0013 completed successfully
# 20/02/09 14:13:54 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=6224888
# 		FILE: Number of bytes written=13711833
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=5371361
# 		HDFS: Number of bytes written=5370513
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=9
# 		Launched reduce tasks=1
# 		Data-local map tasks=9
# 		Total time spent by all maps in occupied slots (ms)=282715
# 		Total time spent by all reduces in occupied slots (ms)=23279
# 		Total time spent by all map tasks (ms)=282715
# 		Total time spent by all reduce tasks (ms)=23279
# 		Total vcore-milliseconds taken by all map tasks=282715
# 		Total vcore-milliseconds taken by all reduce tasks=23279
# 		Total megabyte-milliseconds taken by all map tasks=289500160
# 		Total megabyte-milliseconds taken by all reduce tasks=23837696
# 	Map-Reduce Framework
# 		Map input records=427175
# 		Map output records=427175
# 		Map output bytes=5370522
# 		Map output materialized bytes=6224930
# 		Input split bytes=848
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2075
# 		Reduce shuffle bytes=6224930
# 		Reduce input records=427175
# 		Reduce output records=427175
# 		Spilled Records=854350
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=2456
# 		CPU time spent (ms)=21850
# 		Physical memory (bytes) snapshot=2192592896
# 		Virtual memory (bytes) snapshot=17189261312
# 		Total committed heap usage (bytes)=1700265984
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=5370513
# 	File Output Format Counters
# 		Bytes Written=5370513
# 20/02/09 14:13:54 INFO streaming.StreamJob: Output directory: word_rating
# cat: Unable to write to output stream.
